# %% [markdown]
# # Moore Foundation Site Visit
# ## Camille Scott: "What is it I do, anyway?"
# ### 2015-09-15
# ### UC Davis

# %%
from IPython.display import HTML

# %% [markdown]
# * Data processing logistics are crucial to understanding results in bioinformatics; they are rarely adequately reported. Pydoit!
#   - http://pydoit.org/
#   - https://github.com/dib-lab/2015-petMarSB <-- This is public!
#   - https://github.com/dib-lab/2015-petMarSB/blob/master/notebooks/petmar-genome-completeness.ipynb

# %% [markdown]
# * Purpose-built services with limited scope are more useful and useable than monolithic ones. mygene for programmatic exploration!
#     - http://mygene.info/

# %%
import mygene
mg = mygene.MyGeneInfo()

mg.query('HOX', fields='all', species='zebrafish', verbose=True)
# Out:
# {u'hits': [{u'Vega': u'OTTDARG00000019822',
#    u'ZFIN': u'ZDB-GENE-990415-106',
#    u'_id': u'30341',
#    u'_score': 0.8095548,
#    u'_timestamp': u'2015-08-02T00:00:00',
#    u'accession': {u'genomic': [u'AL645782',
#      u'BX927395',
#      u'DU644552',
#      u'NC_007114',
#      u'NW_003334255',
#      u'X17267',
#      u'X68248'],
#     u'protein': [u'AAI62839',
#      u'AAI62846',
#      u'AAY67919',
#      u'CAA35171',
#      u'CAA48319',
#      u'CAD59113',
#      u'NP_571194',
#      u'P15861'],
#     u'rna': [u'BC162839', u'BC162846', u'DQ060541', u'NM_131119']},
#    u'alias': [u'ZF-22', u'ZF22', u'hox-2.2', u'hox-B6', u'hoxb6', u'z-39'],
#    u'ensembl': {u'gene': u'ENSDARG00000010630',
#     u'protein': u'ENSDARP00000002263',
#     u'transcript': u'ENSDART00000024256'},
#    u'entrezgene': 30341,
#    u'exons': {u'NM_131119': {u'cdsend': 23574896,
#      u'cdsstart': 23573155,
#      u'chr': u'3',
#      u'exons': [[23573155, 23573585], [23574639, 23574896]],
#      u'strand': 1,
#      u'txend': 23574896,
#      u'txstart': 23573155}},
#    u'genomic_pos': {u'chr': u'3',
#     u'end': 23575198,
#     u'start': 23573156,
#     u'strand': 1},
#    u'go': {u'BP': [{u'evidence': u'IEA',
#       u'id': u'GO:0006351',
#       u'term': u'transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0006355',
#       u'term': u'regulation of transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0007275',
#       u'term': u'multicellular organismal development'}],
#     u'CC': {u'evidence': u'IEA', u'id': u'GO:0005634', u'term': u'nucleus'},
#     u'MF': [{u'evidence': u'IEA',
#       u'id': u'GO:0003677',
#       u'term': u'DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0003700',
#       u'term': u'transcription factor activity, sequence-specific DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0043565',
#       u'term': u'sequence-specific DNA binding'}]},
#    u'homologene': {u'genes': [[9606, 3216],
#      [10090, 15414],
#      [10116, 497986],
#      [7955, 30341],
#      [7955, 58053],
#      [8364, 100124320],
#      [9031, 777548],
#      [9598, 749195],
#      [9615, 491056],
#      [9913, 100337380]],
#     u'id': 7366},
#    u'interpro': [{u'desc': u'Homeobox domain',
#      u'id': u'IPR001356',
#      u'short_desc': u'Homeobox_dom'},
#     {u'desc': u'Homeobox protein, antennapedia type',
#      u'id': u'IPR017995',
#      u'short_desc': u'Homeobox_antennapedia'},
#     {u'desc': u'Homeobox protein, antennapedia type, conserved site',
#      u'id': u'IPR001827',
#      u'short_desc': u'Homeobox_Antennapedia_CS'},
#     {u'desc': u'Homeobox, conserved site',
#      u'id': u'IPR017970',
#      u'short_desc': u'Homeobox_CS'},
#     {u'desc': u'Homeodomain, metazoa',
#      u'id': u'IPR020479',
#      u'short_desc': u'Homeobox_metazoa'},
#     {u'desc': u'Homeodomain-like',
#      u'id': u'IPR009057',
#      u'short_desc': u'Homeodomain-like'}],
#    u'ipi': u'IPI00512770',
#    u'name': u'homeobox B6a',
#    u'pfam': u'PF00046',
#    u'pir': u'S32563',
#    u'prosite': u'PS50071',
#    u'refseq': {u'genomic': [u'NC_007114', u'NW_003334255'],
#     u'protein': u'NP_571194',
#     u'rna': u'NM_131119'},
#    u'symbol': u'hoxb6a',
#    u'taxid': 7955,
#    u'type_of_gene': u'protein-coding',
#    u'unigene': u'Dr.132967',
#    u'uniprot': {u'Swiss-Prot': u'P15861'}},
#   {u'Vega': u'OTTDARG00000019756',
#    u'ZFIN': u'ZDB-GENE-980526-70',
#    u'_id': u'30317',
#    u'_score': 0.78003955,
#    u'_timestamp': u'2015-08-02T00:00:00',
#    u'accession': {u'genomic': [u'AL645782',
#      u'BX927395',
#      u'DU644523',
#      u'NC_007114',
#      u'NW_003334255',
#      u'X07381',
#      u'X68248'],
#     u'protein': [u'AAH71493',
#      u'AAY67918',
#      u'CAA30293',
#      u'CAA30294',
#      u'CAA31290',
#      u'CAA48320',
#      u'CAD59114',
#      u'NP_571176',
#      u'P09014'],
#     u'rna': [u'BC071493', u'DQ060540', u'NM_131101', u'X12802']},
#    u'alias': [u'ZF-21',
#     u'ZF21',
#     u'hox-2.1',
#     u'hox-B5',
#     u'hoxb5',
#     u'wu:fc38c09',
#     u'z-18'],
#    u'ensembl': {u'gene': u'ENSDARG00000013057',
#     u'protein': u'ENSDARP00000004270',
#     u'transcript': u'ENSDART00000025449'},
#    u'entrezgene': 30317,
#    u'exons': {u'NM_131101': {u'cdsend': 23578681,
#      u'cdsstart': 23577238,
#      u'chr': u'3',
#      u'exons': [[23577151, 23577818], [23578433, 23579546]],
#      u'strand': 1,
#      u'txend': 23579546,
#      u'txstart': 23577151}},
#    u'generif': [{u'pubmed': u'18832391',
#      u'text': u'Conserved non-coding elements (CNEs) near the zebrafish hoxb5 genes, were characterized.'}],
#    u'genomic_pos': {u'chr': u'3',
#     u'end': 23579547,
#     u'start': 23577143,
#     u'strand': 1},
#    u'go': {u'BP': [{u'evidence': u'IMP',
#       u'id': u'GO:0001708',
#       u'pubmed': 11440248,
#       u'term': u'cell fate specification'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0006351',
#       u'term': u'transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0006355',
#       u'term': u'regulation of transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0007275',
#       u'term': u'multicellular organismal development'},
#      {u'evidence': u'IMP',
#       u'id': u'GO:0007420',
#       u'pubmed': 11440248,
#       u'term': u'brain development'}],
#     u'CC': {u'evidence': u'IEA', u'id': u'GO:0005634', u'term': u'nucleus'},
#     u'MF': [{u'evidence': u'IEA',
#       u'id': u'GO:0003677',
#       u'term': u'DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0003700',
#       u'term': u'transcription factor activity, sequence-specific DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0043565',
#       u'term': u'sequence-specific DNA binding'}]},
#    u'homologene': {u'genes': [[7955, 30317], [7955, 58052]], u'id': 137877},
#    u'interpro': [{u'desc': u'Homeobox domain',
#      u'id': u'IPR001356',
#      u'short_desc': u'Homeobox_dom'},
#     {u'desc': u'Homeobox protein, antennapedia type',
#      u'id': u'IPR017995',
#      u'short_desc': u'Homeobox_antennapedia'},
#     {u'desc': u'Homeobox protein, antennapedia type, conserved site',
#      u'id': u'IPR001827',
#      u'short_desc': u'Homeobox_Antennapedia_CS'},
#     {u'desc': u'Homeobox, conserved site',
#      u'id': u'IPR017970',
#      u'short_desc': u'Homeobox_CS'},
#     {u'desc': u'Homeodomain, metazoa',
#      u'id': u'IPR020479',
#      u'short_desc': u'Homeobox_metazoa'},
#     {u'desc': u'Homeodomain-like',
#      u'id': u'IPR009057',
#      u'short_desc': u'Homeodomain-like'}],
#    u'ipi': u'IPI00493376',
#    u'name': u'homeobox B5a',
#    u'pfam': u'PF00046',
#    u'pir': u'S03671',
#    u'prosite': u'PS50071',
#    u'refseq': {u'genomic': [u'NC_007114', u'NW_003334255'],
#     u'protein': u'NP_571176',
#     u'rna': u'NM_131101'},
#    u'retired': 324688,
#    u'symbol': u'hoxb5a',
#    u'taxid': 7955,
#    u'type_of_gene': u'protein-coding',
#    u'unigene': u'Dr.35792',
#    u'uniprot': {u'Swiss-Prot': u'P09014'}},
#   {u'ZFIN': u'ZDB-GENE-990415-118',
#    u'_id': u'100006598',
#    u'_score': 0.63036716,
#    u'_timestamp': u'2015-05-24T00:00:00',
#    u'accession': {u'genomic': [u'BX322661',
#      u'NC_007120',
#      u'NW_003334755',
#      u'X87753'],
#     u'protein': [u'AAY87055',
#      u'CAA61032',
#      u'CAA74882',
#      u'NP_001119958',
#      u'Q90471',
#      u'XP_005172570'],
#     u'rna': [u'CB359704',
#      u'DQ069273',
#      u'NM_001126486',
#      u'XM_005172513',
#      u'Y14547']},
#    u'alias': [u'HOX-D12', u'hoxd-12', u'hoxd12'],
#    u'ensembl': {u'gene': u'ENSDARG00000059263',
#     u'protein': [u'ENSDARP00000076775',
#      u'ENSDARP00000121699',
#      u'ENSDARP00000129883'],
#     u'transcript': [u'ENSDART00000082339',
#      u'ENSDART00000142842',
#      u'ENSDART00000165502']},
#    u'entrezgene': 100006598,
#    u'exons': {u'NM_001126486': {u'cdsend': 1983783,
#      u'cdsstart': 1981535,
#      u'chr': u'9',
#      u'exons': [[1981084, 1981774], [1983188, 1983807]],
#      u'strand': -1,
#      u'txend': 1983807,
#      u'txstart': 1981084}},
#    u'genomic_pos': {u'chr': u'9',
#     u'end': 1985217,
#     u'start': 1981038,
#     u'strand': -1},
#    u'go': {u'BP': [{u'evidence': u'IEA',
#       u'id': u'GO:0006351',
#       u'term': u'transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0006355',
#       u'term': u'regulation of transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0007275',
#       u'term': u'multicellular organismal development'}],
#     u'CC': {u'evidence': u'IEA', u'id': u'GO:0005634', u'term': u'nucleus'},
#     u'MF': [{u'evidence': u'IEA',
#       u'id': u'GO:0003677',
#       u'term': u'DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0043565',
#       u'term': u'sequence-specific DNA binding'}]},
#    u'homologene': {u'genes': [[9606, 3238],
#      [10090, 15432],
#      [10116, 366082],
#      [7955, 100006598],
#      [9031, 396178],
#      [9544, 100428778],
#      [9598, 459760],
#      [9615, 488413],
#      [9913, 520423]],
#     u'id': 7369},
#    u'interpro': [{u'desc': u'Homeobox domain',
#      u'id': u'IPR001356',
#      u'short_desc': u'Homeobox_dom'},
#     {u'desc': u'Homeobox, conserved site',
#      u'id': u'IPR017970',
#      u'short_desc': u'Homeobox_CS'},
#     {u'desc': u'Homeodomain, metazoa',
#      u'id': u'IPR020479',
#      u'short_desc': u'Homeobox_metazoa'},
#     {u'desc': u'Homeodomain-like',
#      u'id': u'IPR009057',
#      u'short_desc': u'Homeodomain-like'}],
#    u'ipi': u'IPI00499135',
#    u'name': u'homeobox D12a',
#    u'pfam': u'PF00046',
#    u'prosite': u'PS50071',
#    u'refseq': {u'genomic': [u'NC_007120', u'NW_003334755'],
#     u'protein': [u'NP_001119958', u'XP_005172570'],
#     u'rna': [u'NM_001126486', u'XM_005172513']},
#    u'retired': 30406,
#    u'symbol': u'hoxd12a',
#    u'taxid': 7955,
#    u'type_of_gene': u'protein-coding',
#    u'unigene': [u'Dr.75799', u'Dr.151901'],
#    u'uniprot': {u'Swiss-Prot': u'Q90471', u'TrEMBL': u'B0S5Y9'}},
#   {u'Vega': u'OTTDARG00000016368',
#    u'ZFIN': u'ZDB-GENE-980526-533',
#    u'_id': u'30379',
#    u'_score': 0.63036716,
#    u'_timestamp': u'2015-09-13T00:00:00',
#    u'accession': {u'genomic': [u'BX005254',
#      u'M18470',
#      u'NC_007134',
#      u'NW_008805325',
#      u'X68324'],
#     u'protein': [u'AAA50029',
#      u'AAI63205',
#      u'CAA48399',
#      u'CAA74874',
#      u'NP_571219',
#      u'P09074'],
#     u'rna': [u'BC163205', u'NM_131144', u'Y14539']},
#    u'alias': [u'ZF-25', u'hox-3.4', u'hoxc5', u'z-142'],
#    u'ensembl': {u'gene': u'ENSDARG00000070340',
#     u'protein': [u'ENSDARP00000093908', u'ENSDARP00000121862'],
#     u'transcript': [u'ENSDART00000103134', u'ENSDART00000139319']},
#    u'entrezgene': 30379,
#    u'exons': {u'NM_131144': {u'cdsend': 36021454,
#      u'cdsstart': 36019934,
#      u'chr': u'23',
#      u'exons': [[36019870, 36020421], [36021239, 36021708]],
#      u'strand': 1,
#      u'txend': 36021708,
#      u'txstart': 36019870}},
#    u'genomic_pos': {u'chr': u'23',
#     u'end': 36021708,
#     u'start': 36019935,
#     u'strand': 1},
#    u'go': {u'BP': [{u'evidence': u'IEA',
#       u'id': u'GO:0006351',
#       u'term': u'transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0006355',
#       u'term': u'regulation of transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0007275',
#       u'term': u'multicellular organismal development'}],
#     u'CC': {u'evidence': u'IEA', u'id': u'GO:0005634', u'term': u'nucleus'},
#     u'MF': [{u'evidence': u'IEA',
#       u'id': u'GO:0003677',
#       u'term': u'DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0003700',
#       u'term': u'transcription factor activity, sequence-specific DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0043565',
#       u'term': u'sequence-specific DNA binding'}]},
#    u'homologene': {u'genes': [[9606, 3222],
#      [10090, 15424],
#      [10116, 315341],
#      [7955, 30379],
#      [8364, 100487879],
#      [9598, 467010],
#      [9615, 102152615],
#      [9913, 100140629]],
#     u'id': 41296},
#    u'interpro': [{u'desc': u'Homeobox domain',
#      u'id': u'IPR001356',
#      u'short_desc': u'Homeobox_dom'},
#     {u'desc': u'Homeobox protein, antennapedia type',
#      u'id': u'IPR017995',
#      u'short_desc': u'Homeobox_antennapedia'},
#     {u'desc': u'Homeobox protein, antennapedia type, conserved site',
#      u'id': u'IPR001827',
#      u'short_desc': u'Homeobox_Antennapedia_CS'},
#     {u'desc': u'Homeobox, conserved site',
#      u'id': u'IPR017970',
#      u'short_desc': u'Homeobox_CS'},
#     {u'desc': u'Homeodomain, metazoa',
#      u'id': u'IPR020479',
#      u'short_desc': u'Homeobox_metazoa'},
#     {u'desc': u'Homeodomain-like',
#      u'id': u'IPR009057',
#      u'short_desc': u'Homeodomain-like'}],
#    u'ipi': u'IPI00934138',
#    u'name': u'homeobox C5a',
#    u'pfam': u'PF00046',
#    u'pir': u'S48125',
#    u'prosite': u'PS50071',
#    u'refseq': {u'genomic': [u'NC_007134', u'NW_008805325'],
#     u'protein': u'NP_571219',
#     u'rna': u'NM_131144'},
#    u'symbol': u'hoxc5a',
#    u'taxid': 7955,
#    u'type_of_gene': u'protein-coding',
#    u'unigene': u'Dr.132198',
#    u'uniprot': {u'Swiss-Prot': u'P09074'}},
#   {u'Vega': u'OTTDARG00000017442',
#    u'ZFIN': u'ZDB-GENE-990415-116',
#    u'_id': u'30404',
#    u'_score': 0.5724417,
#    u'_timestamp': u'2015-05-24T00:00:00',
#    u'accession': {u'genomic': [u'BX322661',
#      u'NC_007120',
#      u'NW_003334755',
#      u'U51403',
#      u'U51421',
#      u'X87750'],
#     u'protein': [u'AAB38626',
#      u'AAB38643',
#      u'AAH71329',
#      u'AAI53659',
#      u'CAA61029',
#      u'CAA74877',
#      u'NP_571241',
#      u'Q90469'],
#     u'rna': [u'BC071329',
#      u'BC153658',
#      u'CK864624',
#      u'CT704711',
#      u'NM_131166',
#      u'Y14542']},
#    u'alias': [u'HOX-D10', u'hoxd-10', u'hoxd10', u'z-82'],
#    u'ensembl': {u'gene': u'ENSDARG00000057859',
#     u'protein': u'ENSDARP00000075055',
#     u'transcript': u'ENSDART00000080608'},
#    u'entrezgene': 30404,
#    u'exons': {u'NM_131166': {u'cdsend': 1969136,
#      u'cdsstart': 1967422,
#      u'chr': u'9',
#      u'exons': [[1966908, 1967697], [1968412, 1969250]],
#      u'strand': -1,
#      u'txend': 1969250,
#      u'txstart': 1966908}},
#    u'genomic_pos': {u'chr': u'9',
#     u'end': 1969274,
#     u'start': 1966910,
#     u'strand': -1},
#    u'go': {u'BP': [{u'evidence': u'IEA',
#       u'id': u'GO:0006351',
#       u'term': u'transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0006355',
#       u'term': u'regulation of transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0007275',
#       u'term': u'multicellular organismal development'}],
#     u'CC': {u'evidence': u'IEA', u'id': u'GO:0005634', u'term': u'nucleus'},
#     u'MF': [{u'evidence': u'IEA',
#       u'id': u'GO:0003677',
#       u'term': u'DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0043565',
#       u'term': u'sequence-specific DNA binding'}]},
#    u'homologene': {u'genes': [[9606, 3236],
#      [10090, 15430],
#      [10116, 303991],
#      [7955, 30404],
#      [8364, 100038085],
#      [9031, 771246],
#      [9598, 739607],
#      [9615, 609973],
#      [9913, 540251]],
#     u'id': 1619},
#    u'interpro': [{u'desc': u'Homeobox domain',
#      u'id': u'IPR001356',
#      u'short_desc': u'Homeobox_dom'},
#     {u'desc': u'Homeobox, conserved site',
#      u'id': u'IPR017970',
#      u'short_desc': u'Homeobox_CS'},
#     {u'desc': u'Homeodomain, metazoa',
#      u'id': u'IPR020479',
#      u'short_desc': u'Homeobox_metazoa'},
#     {u'desc': u'Homeodomain-like',
#      u'id': u'IPR009057',
#      u'short_desc': u'Homeodomain-like'}],
#    u'ipi': [u'IPI00551911', u'IPI00996139'],
#    u'name': u'homeobox D10a',
#    u'pfam': u'PF00046',
#    u'prosite': u'PS50071',
#    u'refseq': {u'genomic': [u'NC_007120', u'NW_003334755'],
#     u'protein': u'NP_571241',
#     u'rna': u'NM_131166'},
#    u'symbol': u'hoxd10a',
#    u'taxid': 7955,
#    u'type_of_gene': u'protein-coding',
#    u'unigene': u'Dr.75795',
#    u'uniprot': {u'Swiss-Prot': u'Q90469', u'TrEMBL': u'E9QBR9'}},
#   {u'Vega': u'OTTDARG00000016363',
#    u'ZFIN': u'ZDB-GENE-990415-113',
#    u'_id': u'30346',
#    u'_score': 0.5724417,
#    u'_timestamp': u'2015-08-02T00:00:00',
#    u'accession': {u'genomic': [u'AF071265',
#      u'BX005254',
#      u'DU644831',
#      u'NC_007134',
#      u'NW_008805325',
#      u'X17266'],
#     u'protein': [u'AAD15958',
#      u'AAH83307',
#      u'AAI65049',
#      u'AAY67932',
#      u'CAA35170',
#      u'CAA74881',
#      u'NP_571198',
#      u'P15862'],
#     u'rna': [u'BC083307', u'BC165049', u'DQ060554', u'NM_131123', u'Y14546']},
#    u'alias': [u'HOX-C6', u'ZF-61', u'hoxc-6', u'hoxc6', u'zgc:101882'],
#    u'ensembl': {u'gene': u'ENSDARG00000070343',
#     u'protein': [u'ENSDARP00000093809', u'ENSDARP00000107797'],
#     u'transcript': [u'ENSDART00000103035', u'ENSDART00000130090']},
#    u'entrezgene': 30346,
#    u'exons': {u'NM_131123': {u'cdsend': 36017974,
#      u'cdsstart': 36016668,
#      u'chr': u'23',
#      u'exons': [[36016668, 36017071], [36017681, 36017974]],
#      u'strand': 1,
#      u'txend': 36017974,
#      u'txstart': 36016668}},
#    u'genomic_pos': {u'chr': u'23',
#     u'end': 36018761,
#     u'start': 36016455,
#     u'strand': 1},
#    u'go': {u'BP': [{u'evidence': u'IEA',
#       u'id': u'GO:0006351',
#       u'term': u'transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0006355',
#       u'term': u'regulation of transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0007275',
#       u'term': u'multicellular organismal development'}],
#     u'CC': {u'evidence': u'IEA', u'id': u'GO:0005634', u'term': u'nucleus'},
#     u'MF': [{u'evidence': u'IEA',
#       u'id': u'GO:0003677',
#       u'term': u'DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0003700',
#       u'term': u'transcription factor activity, sequence-specific DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0043565',
#       u'term': u'sequence-specific DNA binding'}]},
#    u'homologene': {u'genes': [[9606, 3223],
#      [10090, 15425],
#      [10116, 252885],
#      [7955, 30346],
#      [8364, 101733663],
#      [9031, 100858368],
#      [9598, 100607977],
#      [9615, 486499],
#      [9913, 317660]],
#     u'id': 19533},
#    u'interpro': [{u'desc': u'Homeobox domain',
#      u'id': u'IPR001356',
#      u'short_desc': u'Homeobox_dom'},
#     {u'desc': u'Homeobox protein, antennapedia type, conserved site',
#      u'id': u'IPR001827',
#      u'short_desc': u'Homeobox_Antennapedia_CS'},
#     {u'desc': u'Homeobox, conserved site',
#      u'id': u'IPR017970',
#      u'short_desc': u'Homeobox_CS'},
#     {u'desc': u'Homeodomain, metazoa',
#      u'id': u'IPR020479',
#      u'short_desc': u'Homeobox_metazoa'},
#     {u'desc': u'Homeodomain-like',
#      u'id': u'IPR009057',
#      u'short_desc': u'Homeodomain-like'}],
#    u'ipi': u'IPI00494357',
#    u'name': u'homeobox C6a',
#    u'pfam': u'PF00046',
#    u'pir': u'S08639',
#    u'prosite': u'PS50071',
#    u'refseq': {u'genomic': [u'NC_007134', u'NW_008805325'],
#     u'protein': u'NP_571198',
#     u'rna': u'NM_131123'},
#    u'symbol': u'hoxc6a',
#    u'taxid': 7955,
#    u'type_of_gene': u'protein-coding',
#    u'unigene': u'Dr.132203',
#    u'uniprot': {u'Swiss-Prot': u'P15862'}},
#   {u'ZFIN': u'ZDB-GENE-980526-532',
#    u'_id': u'30421',
#    u'_score': 0.53390026,
#    u'_timestamp': u'2015-05-24T00:00:00',
#    u'accession': {u'genomic': [u'AB175067',
#      u'CU013512',
#      u'NC_007134',
#      u'NW_008805325'],
#     u'protein': [u'AAH95299',
#      u'AAI65158',
#      u'AAY67929',
#      u'CAA42691',
#      u'NP_001128157',
#      u'P28174',
#      u'XP_005162422',
#      u'XP_005162423',
#      u'XP_005162424'],
#     u'rna': [u'AB175333',
#      u'BC095299',
#      u'BC154496',
#      u'BC165158',
#      u'DQ060551',
#      u'NM_001134685',
#      u'X60095',
#      u'XM_005162365',
#      u'XM_005162366',
#      u'XM_005162367']},
#    u'alias': [u'HOX-114', u'zgc:110503'],
#    u'ensembl': {u'gene': u'ENSDARG00000070339',
#     u'protein': [u'ENSDARP00000076907',
#      u'ENSDARP00000076908',
#      u'ENSDARP00000129026',
#      u'ENSDARP00000129398'],
#     u'transcript': [u'ENSDART00000082472',
#      u'ENSDART00000082473',
#      u'ENSDART00000128533',
#      u'ENSDART00000137507',
#      u'ENSDART00000154825']},
#    u'entrezgene': 30421,
#    u'exons': {u'NM_001134685': {u'cdsend': 36049265,
#      u'cdsstart': 36046234,
#      u'chr': u'23',
#      u'exons': [[35988493, 35988604],
#       [36028419, 36028471],
#       [36046220, 36046390],
#       [36046580, 36046848],
#       [36048897, 36050239]],
#      u'strand': 1,
#      u'txend': 36050239,
#      u'txstart': 35988493}},
#    u'genomic_pos': {u'chr': u'23',
#     u'end': 36050568,
#     u'start': 35988416,
#     u'strand': 1},
#    u'go': {u'BP': [{u'evidence': u'IEA',
#       u'id': u'GO:0006355',
#       u'term': u'regulation of transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0007275',
#       u'term': u'multicellular organismal development'}],
#     u'CC': {u'evidence': u'IEA', u'id': u'GO:0005634', u'term': u'nucleus'},
#     u'MF': [{u'evidence': u'IEA',
#       u'id': u'GO:0003677',
#       u'term': u'DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0043565',
#       u'term': u'sequence-specific DNA binding'}]},
#    u'interpro': [{u'desc': u'Homeobox domain',
#      u'id': u'IPR001356',
#      u'short_desc': u'Homeobox_dom'},
#     {u'desc': u'Homeobox, conserved site',
#      u'id': u'IPR017970',
#      u'short_desc': u'Homeobox_CS'},
#     {u'desc': u'Homeodomain, metazoa',
#      u'id': u'IPR020479',
#      u'short_desc': u'Homeobox_metazoa'},
#     {u'desc': u'Homeodomain-like',
#      u'id': u'IPR009057',
#      u'short_desc': u'Homeodomain-like'}],
#    u'ipi': u'IPI00931602',
#    u'name': u'homeo box C3a',
#    u'pfam': u'PF00046',
#    u'prosite': u'PS50071',
#    u'refseq': {u'genomic': [u'NC_007134', u'NW_008805325'],
#     u'protein': [u'NP_001128157',
#      u'XP_005162422',
#      u'XP_005162423',
#      u'XP_005162424'],
#     u'rna': [u'NM_001134685',
#      u'XM_005162365',
#      u'XM_005162366',
#      u'XM_005162367']},
#    u'retired': 100151318,
#    u'symbol': u'hoxc3a',
#    u'taxid': 7955,
#    u'type_of_gene': u'protein-coding',
#    u'unigene': [u'Dr.510', u'Dr.132202']},
#   {u'Vega': u'OTTDARG00000015149',
#    u'ZFIN': u'ZDB-GENE-000823-5',
#    u'_id': u'58051',
#    u'_score': 0.5175482,
#    u'_timestamp': u'2015-05-31T00:00:00',
#    u'accession': {u'genomic': [u'AF071243',
#      u'AL645756',
#      u'CR382300',
#      u'DU644665',
#      u'NC_007130',
#      u'NW_001877953'],
#     u'protein': [u'AAD15937',
#      u'AAI62701',
#      u'AAY67909',
#      u'CAC34565',
#      u'CAC34566',
#      u'CAD52136',
#      u'CAD52137',
#      u'NP_571611',
#      u'Q98SI1',
#      u'XP_005159579',
#      u'XP_009292446',
#      u'XP_009292447'],
#     u'rna': [u'AJ306430',
#      u'AJ306431',
#      u'BC162701',
#      u'DQ060531',
#      u'NM_131536',
#      u'XM_005159522',
#      u'XM_009294171',
#      u'XM_009294172']},
#    u'alias': [u'Hox-a1', u'hoxa3a', u'id:ibd3526', u'z-4'],
#    u'ensembl': {u'gene': u'ENSDARG00000104307',
#     u'protein': [u'ENSDARP00000133272', u'ENSDARP00000133812'],
#     u'transcript': [u'ENSDART00000163546', u'ENSDART00000167757']},
#    u'entrezgene': 58051,
#    u'exons': {u'NM_131536': {u'cdsend': 20214446,
#      u'cdsstart': 20213261,
#      u'chr': u'19',
#      u'exons': [[20213165, 20213901], [20214096, 20214468]],
#      u'strand': 1,
#      u'txend': 20214468,
#      u'txstart': 20213165}},
#    u'genomic_pos': {u'chr': u'19',
#     u'end': 20214801,
#     u'start': 20213166,
#     u'strand': 1},
#    u'go': {u'BP': [{u'evidence': u'IEA',
#       u'id': u'GO:0006351',
#       u'term': u'transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0006355',
#       u'term': u'regulation of transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0007275',
#       u'term': u'multicellular organismal development'}],
#     u'CC': {u'evidence': u'IEA', u'id': u'GO:0005634', u'term': u'nucleus'},
#     u'MF': [{u'evidence': u'IEA',
#       u'id': u'GO:0003677',
#       u'term': u'DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0043565',
#       u'term': u'sequence-specific DNA binding'}]},
#    u'homologene': {u'genes': [[9606, 3198],
#      [10090, 15394],
#      [10116, 103690132],
#      [7955, 58051],
#      [8364, 493379],
#      [9031, 374051],
#      [9544, 700723],
#      [9598, 463308],
#      [9615, 482367],
#      [9913, 537889]],
#     u'id': 4032},
#    u'interpro': [{u'desc': u'Homeobox domain',
#      u'id': u'IPR001356',
#      u'short_desc': u'Homeobox_dom'},
#     {u'desc': u'Homeobox, conserved site',
#      u'id': u'IPR017970',
#      u'short_desc': u'Homeobox_CS'},
#     {u'desc': u'Homeodomain, metazoa',
#      u'id': u'IPR020479',
#      u'short_desc': u'Homeobox_metazoa'},
#     {u'desc': u'Homeodomain-like',
#      u'id': u'IPR009057',
#      u'short_desc': u'Homeodomain-like'}],
#    u'ipi': [u'IPI00494329', u'IPI00494805'],
#    u'name': u'homeobox A1a',
#    u'pfam': u'PF00046',
#    u'prosite': u'PS50071',
#    u'refseq': {u'genomic': [u'NC_007130', u'NW_001877953'],
#     u'protein': [u'NP_571611',
#      u'XP_005159579',
#      u'XP_009292446',
#      u'XP_009292447'],
#     u'rna': [u'NM_131536', u'XM_005159522', u'XM_009294171', u'XM_009294172']},
#    u'retired': 338133,
#    u'symbol': u'hoxa1a',
#    u'taxid': 7955,
#    u'type_of_gene': u'protein-coding',
#    u'unigene': u'Dr.83046',
#    u'uniprot': {u'Swiss-Prot': u'Q98SI1', u'TrEMBL': u'B3DHB1'}},
#   {u'Vega': u'OTTDARG00000019821',
#    u'ZFIN': u'ZDB-GENE-990415-105',
#    u'_id': u'30340',
#    u'_score': 0.5175482,
#    u'_timestamp': u'2015-08-02T00:00:00',
#    u'accession': {u'genomic': [u'AF071252',
#      u'AL645782',
#      u'BX927395',
#      u'M24085',
#      u'NC_007114',
#      u'NW_003334255'],
#     u'protein': [u'AAA56866',
#      u'AAD15945',
#      u'AAI62840',
#      u'AAI62844',
#      u'CAA74284',
#      u'CAD59115',
#      u'DAA05783',
#      u'NP_571193',
#      u'P22574'],
#     u'rna': [u'BC162840', u'BC162844', u'BK005804', u'NM_131118', u'Y13946']},
#    u'alias': [u'HOX-B4', u'Z-17', u'ZF-13', u'hoxb4', u'zf13'],
#    u'ensembl': {u'gene': u'ENSDARG00000013533',
#     u'protein': [u'ENSDARP00000008458', u'ENSDARP00000125694'],
#     u'transcript': [u'ENSDART00000012470', u'ENSDART00000151584']},
#    u'entrezgene': 30340,
#    u'exons': {u'NM_131118': {u'cdsend': 23592940,
#      u'cdsstart': 23591259,
#      u'chr': u'3',
#      u'exons': [[23591259, 23591683], [23592623, 23592940]],
#      u'strand': 1,
#      u'txend': 23592940,
#      u'txstart': 23591259}},
#    u'generif': [{u'pubmed': u'16860306',
#      u'text': u'the similarity of hoxb3a/Hoxa3 regulatory mechanisms reflect the shared descent of both genes from a single ancestral paralog, expression of both genes in the posterior hindbrain and spinal cord in embryo'},
#     {u'pubmed': u'18627100',
#      u'text': u'hoxb4a in combination with its paralogs may play a significant role in the development of precerebellar, vagal, and pectoral fin neuronal subtypes'},
#     {u'pubmed': u'19536294',
#      u'text': u'continuous presence of hoxb4a positive neurons may provide a developmental plasticity for behavior-specific circuits to accommodate experience- and growth-related changes'}],
#    u'genomic_pos': {u'chr': u'3',
#     u'end': 23593434,
#     u'start': 23580291,
#     u'strand': 1},
#    u'go': {u'BP': [{u'evidence': u'IEA',
#       u'id': u'GO:0006351',
#       u'term': u'transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0006355',
#       u'term': u'regulation of transcription, DNA-templated'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0007275',
#       u'term': u'multicellular organismal development'}],
#     u'CC': {u'evidence': u'IEA', u'id': u'GO:0005634', u'term': u'nucleus'},
#     u'MF': [{u'evidence': u'IEA',
#       u'id': u'GO:0003677',
#       u'term': u'DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0003700',
#       u'term': u'transcription factor activity, sequence-specific DNA binding'},
#      {u'evidence': u'IEA',
#       u'id': u'GO:0043565',
#       u'term': u'sequence-specific DNA binding'}]},
#    u'homologene': {u'genes': [[9606, 3214],
#      [10090, 15412],
#      [10116, 497988],
#      [7955, 30340],
#      [8364, 548393],
#      [9031, 396230],
#      [9598, 749218],
#      [9615, 608915],
#      [9913, 768240]],
#     u'id': 32095},
#    u'interpro': [{u'desc': u'Homeobox domain',
#      u'id': u'IPR001356',
#      u'short_desc': u'Homeobox_dom'},
#     {u'desc': u'Homeobox protein, antennapedia type',
#      u'id': u'IPR017995',
#      u'short_desc': u'Homeobox_antennapedia'},
#     {u'desc': u'Homeobox protein, antennapedia type, conserved site',
#      u'id': u'IPR001827',
#      u'short_desc': u'Homeobox_Antennapedia_CS'},
#     {u'desc': u'Homeobox, conserved site',
#      u'id': u'IPR017970',
#      u'short_desc': u'Homeobox_CS'},
#     {u'desc': u'Homeodomain, metazoa',
#      u'id': u'IPR020479',
#      u'short_desc': u'Homeobox_metazoa'},
#     {u'desc': u'Homeodomain-like',
#      u'id': u'IPR009057',
#      u'short_desc': u'Homeodomain-like'}],
#    u'ipi': u'IPI00499387',
#    u'name': u'homeobox B4a',
#    u'pfam': u'PF00046',
#    u'pir': u'JT0489',
#    u'prosite': u'PS50071',
#    u'refseq': {u'genomic': [u'NC_007114', u'NW_003334255'],
#     u'protein': u'NP_571193',
#     u'rna': u'NM_131118'},
#    u'symbol': u'hoxb4a',
#    u'taxid': 7955,
#    u'type_of_gene': u'protein-coding',
#    u'unigene': u'Dr.133609',
#    u'uniprot': {u'Swiss-Prot': u'P22574', u'TrEMBL': [u'B3DHP6', u'Q0D251']}}],
#  u'max_score': 0.8095548,
#  u'took': 37,
#  u'total': 9}

# %% [markdown]
# * Looking at individual projects as iterative processes requires 1) and 2).  pweave connects the processing with the description and let's me crank the wheel faster.
#     - https://github.com/dib-lab/2015-petMarSB/blob/master/doc/2015-petMarSB.draft.texw
#     - https://github.com/dib-lab/2015-petMarSB/blob/master/doc/2015-petMarSB.draft.tex
#     - https://github.com/dib-lab/2015-petMarSB/blob/master/doc/2015-petMarSB.draft.pdf

# %% [markdown]
# Putting it all together: we can construct complex analyses from these simple building blocks. This has been put to practice for the [lamprey transcriptome](http://nbviewer.ipython.org/github/dib-lab/2015-petMarSB/blob/master/notebooks/petmar-genome-completeness.ipynb).

# %% [markdown]
# ![proposed craniate phylogenies](http://icb.oxfordjournals.org/content/50/1/130/F2.medium.gif)
