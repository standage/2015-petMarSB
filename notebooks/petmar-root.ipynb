# %% [markdown]
# # Lamprey Transcriptome Analysis

# %% [markdown]
# ```
# Camille Scott [camille dot scott dot w @gmail.com] [@camille_codon]
#
# camillescott.github.io
#
# Lab for Genomics, Evolution, and Development
# Michigan State University
# ```

# %% [markdown]
# ## About

# %% [markdown]
# This notebook is the entry point for the [Petromyzon marinus](http://nas.er.usgs.gov/queries/FactSheet.aspx?speciesID=836) (sea lamprey) de novo transcriptome analysis. This entry notebook contains links for the others, and code to collect and format data for the other notebooks. It should be run before all other notebooks in order to generate the requisite data.

# %% [markdown]
# ## Contents

# %% [markdown]
# 1. [Transcript Analysis Notebook](petmar-transcripts.ipynb)
# 2. [Tissue Analysis Notebook](petmar-tissues.ipynb)
# 3. [Protein Analysis Notebook](petmar-proteins.ipynb)
# 4. [Taxonomic Analysis Notebook](petmar-taxonomy.ipynb)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from libs import *
# %run -i common.ipy
# Out:
# ** Using data resources found in ../resources.json
# ** Using config found in ../config.json

# %%
wdir()
# Out:
# u'../_work/'

# %% [markdown]
# ### Databases

# %%
resources_df[resources_df.meta_type != 'sample']
# Out:
#                      access condition  db_type           filename flowcell  \
# Myxinidae_pep  remote_query       NaN     prot     Myx.pep.all.fa      NaN
# braFlo_pep     remote_query       NaN     prot  braFlo.pep.all.fa      NaN
# danRer_pep      remote_file       NaN     prot      danRer.pep.fa      NaN
# homSap_pep      remote_file       NaN     prot      homSap.pep.fa      NaN
# lamp10          remote_file       NaN     nucl       lamp10.fasta      NaN
# musMus_pep      remote_file       NaN     prot      musMus.pep.fa      NaN
# petMar2         remote_file       NaN     nucl         petMar2.fa      NaN
# petMar2_cdna    remote_file       NaN     nucl    petMar2.cdna.fa      NaN
# petMar2_cds     remote_file       NaN     nucl     petMar2.cds.fa      NaN
# petMar2_gtf     remote_file       NaN  feature        petMar2.gtf      NaN
# petMar2_ncrna   remote_file       NaN     nucl   petMar2.ncrna.fa      NaN
# petMar2_pep     remote_file       NaN     prot     petMar2.pep.fa      NaN
#
#               label       meta_type paired phred   q_type strand  \
# Myxinidae_pep   NaN  fasta_database    NaN   NaN  uniprot    NaN
# braFlo_pep      NaN  fasta_database    NaN   NaN  uniprot    NaN
# danRer_pep      NaN  fasta_database    NaN   NaN      NaN    NaN
# homSap_pep      NaN  fasta_database    NaN   NaN      NaN    NaN
# lamp10          NaN        assembly    NaN   NaN      NaN    NaN
# musMus_pep      NaN  fasta_database    NaN   NaN      NaN    NaN
# petMar2         NaN  fasta_database    NaN   NaN      NaN    NaN
# petMar2_cdna    NaN  fasta_database    NaN   NaN      NaN    NaN
# petMar2_cds     NaN  fasta_database    NaN   NaN      NaN    NaN
# petMar2_gtf     NaN    gtf_database    NaN   NaN      NaN    NaN
# petMar2_ncrna   NaN  fasta_database    NaN   NaN      NaN    NaN
# petMar2_pep     NaN  fasta_database    NaN   NaN      NaN    NaN
#
#                                         terms tissue  \
# Myxinidae_pep                   taxonomy:7762    NaN
# braFlo_pep     organism:7739+AND+keyword:1185    NaN
# danRer_pep                                NaN    NaN
# homSap_pep                                NaN    NaN
# lamp10                                    NaN    NaN
# musMus_pep                                NaN    NaN
# petMar2                                   NaN    NaN
# petMar2_cdna                              NaN    NaN
# petMar2_cds                               NaN    NaN
# petMar2_gtf                               NaN    NaN
# petMar2_ncrna                             NaN    NaN
# petMar2_pep                               NaN    NaN
#
#                                                              url    size
# Myxinidae_pep                                                NaN    1004
# braFlo_pep                                                   NaN   28544
# danRer_pep     ftp://ftp.ensembl.org/pub/release-75/fasta/dan...   43153
# homSap_pep     ftp://ftp.ensembl.org/pub/release-74/fasta/hom...  104763
# lamp10         http://athyra.ged.msu.edu/~camille/lamprey/lam...  715345
# musMus_pep     ftp://ftp.ensembl.org/pub/release-75/fasta/mus...   52165
# petMar2        ftp://ftp.ensembl.org/pub/release-75/fasta/pet...   25006
# petMar2_cdna   ftp://ftp.ensembl.org/pub/release-75/fasta/pet...   11489
# petMar2_cds    ftp://ftp.ensembl.org/pub/release-75/fasta/pet...   11442
# petMar2_gtf    http://ftp.ensembl.org/pub/release-75/gtf/petr...       0
# petMar2_ncrna  ftp://ftp.ensembl.org/pub/release-75/fasta/pet...    2652
# petMar2_pep    ftp://ftp.ensembl.org/pub/release-75/fasta/pet...   11442

# %% [markdown]
# ### Samples

# %%
sample_df
# Out:
#                        access        condition db_type  \
# 614GMAAXX_1_1_pf   local_file            stg18    nucl
# 614GMAAXX_2_1_pf   local_file            stg20    nucl
# 614GMAAXX_3_1_pf   local_file           stg22a    nucl
# 614GMAAXX_4_1_pf   local_file           stg22b    nucl
# 614GMAAXX_6_1_pf   local_file            stg23    nucl
# 614GMAAXX_7_1_pf   local_file          stg24c1    nucl
# 614GMAAXX_8_1_pf   local_file          stg24c2    nucl
# AB057JABXX_s_7_pe  local_file           larval    nucl
# AI                 local_file            adult    nucl
# AK                 local_file            adult    nucl
# BB0582ABXX_s_3_pe  local_file           larval    nucl
# BB0582ABXX_s_4_pe  local_file             pars    nucl
# BB0582ABXX_s_5_pe  local_file            adult    nucl
# BB0582ABXX_s_6_pe  local_file          adult_1    nucl
# BB0582ABXX_s_7_pe  local_file          adult_2    nucl
# BB0582ABXX_s_8_pe  local_file          adult_3    nucl
# FW1-Gill           local_file           freshw    nucl
# FW1-Intestine      local_file           freshw    nucl
# FW1-Kidney         local_file           freshw    nucl
# G81-a              local_file    larval_a_tfm0    nucl
# G81-b              local_file    larval_b_tfm0    nucl
# G82-a              local_file    larval_a_tfm6    nucl
# G82-b              local_file    larval_b_tfm6    nucl
# G83-a              local_file   larval_a_tfm12    nucl
# G83-b              local_file   larval_b_tfm12    nucl
# Gill               local_file                     nucl
# JV1_liver          local_file              juv    nucl
# JV_intest          local_file            juv_b    nucl
# JVa_liver          local_file            juv_1    nucl
# JVb_liver          local_file            juv_a    nucl
# Kidney             local_file                     nucl
# L81-a              local_file    larval_a_tfm0    nucl
# L81-b              local_file    larval_b_tfm0    nucl
# L82-a              local_file    larval_a_tfm6    nucl
# L82-b              local_file    larval_b_tfm6    nucl
# L83-1-a            local_file  larval_a1_tfm12    nucl
# L83-1-b            local_file  larval_b1_tfm12    nucl
# L83-a              local_file   larval_a_tfm12    nucl
# L83-b              local_file   larval_b_tfm12    nucl
# LI                 local_file           larval    nucl
# LK                 local_file           larval    nucl
# Lips               local_file                     nucl
# M0_liver           local_file           larval    nucl
# M2_liver           local_file             stg2    nucl
# M5_liver           local_file             stg5    nucl
# Monocytes          local_file                     nucl
# Muscle             local_file          m_sperm    nucl
# Neutrophils        local_file                     nucl
# OFHS               local_file            f_ovu    nucl
# POF-eye            local_file         f_preovu    nucl
# POF-ts             local_file         f_preovu    nucl
# PSMGill            local_file       m_presperm    nucl
# Rope               local_file          adult_m    nucl
# SMGill             local_file          m_sperm    nucl
# SMHS               local_file          m_sperm    nucl
# SN                 local_file                     nucl
# SPDI               local_file      distal_pars    nucl
# SPK                local_file             pars    nucl
# SPPI               local_file        prox_pars    nucl
# SW2-Gill           local_file            saltw    nucl
# SW2-Intestine-a    local_file          saltw_a    nucl
# SW2-Intestine-b    local_file          saltw_b    nucl
# SW2-Kidney         local_file            saltw    nucl
# Stg-1-Intestine    local_file             stg1    nucl
# Stg-1-Kidney       local_file             stg1    nucl
# Stg-2-Intestine    local_file             stg2    nucl
# Stg-2-Kidney       local_file             stg2    nucl
# Stg-3-Intestine    local_file             stg3    nucl
# Stg-3-Kidney       local_file             stg3    nucl
# Stg-4-Intestine    local_file             stg4    nucl
# Stg-4-Kidney       local_file             stg4    nucl
# Stg-5-Intestine    local_file             stg5    nucl
# Stg-5-Kidney       local_file             stg5    nucl
# Stg-6-Intestine    local_file             stg6    nucl
# Stg-6-Kidney       local_file             stg6    nucl
# Stg-7-Intestine    local_file             stg7    nucl
# Stg-7-Kidney       local_file             stg7    nucl
# brain_paired       local_file                     nucl
# mssm_single_s1     local_file             ctrl    nucl
# mssm_single_s2     local_file             ctrl    nucl
# mssm_single_s3     local_file             day3    nucl
# mssm_single_s5     local_file             day3    nucl
# mssm_single_s6     local_file            day21    nucl
# mssm_single_s7     local_file            day21    nucl
#
#                                        filename flowcell  \
# 614GMAAXX_1_1_pf      614GMAAXX_1_1_pf.qc.fq.gz    614GM
# 614GMAAXX_2_1_pf      614GMAAXX_2_1_pf.qc.fq.gz    614GM
# 614GMAAXX_3_1_pf      614GMAAXX_3_1_pf.qc.fq.gz    614GM
# 614GMAAXX_4_1_pf      614GMAAXX_4_1_pf.qc.fq.gz    614GM
# 614GMAAXX_6_1_pf      614GMAAXX_6_1_pf.qc.fq.gz    614GM
# 614GMAAXX_7_1_pf      614GMAAXX_7_1_pf.qc.fq.gz    614GM
# 614GMAAXX_8_1_pf      614GMAAXX_8_1_pf.qc.fq.gz    614GM
# AB057JABXX_s_7_pe  AB057JABXX_s_7_pe.trim.fq.gz    AB057
# AI                                     AI.fq.gz    614GM
# AK                                     AK.fq.gz    614GM
# BB0582ABXX_s_3_pe  BB0582ABXX_s_3_pe.trim.fq.gz    BB058
# BB0582ABXX_s_4_pe  BB0582ABXX_s_4_pe.trim.fq.gz    BB058
# BB0582ABXX_s_5_pe  BB0582ABXX_s_5_pe.trim.fq.gz    BB058
# BB0582ABXX_s_6_pe  BB0582ABXX_s_6_pe.trim.fq.gz    BB058
# BB0582ABXX_s_7_pe  BB0582ABXX_s_7_pe.trim.fq.gz    BB058
# BB0582ABXX_s_8_pe  BB0582ABXX_s_8_pe.trim.fq.gz    BB058
# FW1-Gill                         FW1-Gill.fq.gz    614H7
# FW1-Intestine               FW1-Intestine.fq.gz    614H7
# FW1-Kidney                     FW1-Kidney.fq.gz    614H7
# G81-a                               G81-a.fq.gz    614GT
# G81-b                               G81-b.fq.gz    61HWC
# G82-a                               G82-a.fq.gz    614GT
# G82-b                               G82-b.fq.gz    61HWC
# G83-a                               G83-a.fq.gz    614GT
# G83-b                               G83-b.fq.gz    61HWC
# Gill                                 Gill.fq.gz    42UL4
# JV1_liver                       JV1_liver.fq.gz    42UKJ
# JV_intest                       JV_intest.fq.gz    42UKJ
# JVa_liver                       JVa_liver.fq.gz    42UKJ
# JVb_liver                       JVb_liver.fq.gz    42UKJ
# Kidney                             Kidney.fq.gz    42UL4
# L81-a                               L81-a.fq.gz    614GT
# L81-b                               L81-b.fq.gz    61HWC
# L82-a                               L82-a.fq.gz    614GT
# L82-b                               L82-b.fq.gz    61HWC
# L83-1-a                           L83-1-a.fq.gz    614GT
# L83-1-b                           L83-1-b.fq.gz    61HWC
# L83-a                               L83-a.fq.gz    614GT
# L83-b                               L83-b.fq.gz    61HWC
# LI                                     LI.fq.gz    434JM
# LK                                     LK.fq.gz    434JM
# Lips                                 Lips.fq.gz    42UL4
# M0_liver                         M0_liver.fq.gz    42UKJ
# M2_liver                         M2_liver.fq.gz    42UKJ
# M5_liver                         M5_liver.fq.gz    42UKJ
# Monocytes                       Monocytes.fq.gz    61504
# Muscle                             Muscle.fq.gz    42UL4
# Neutrophils                   Neutrophils.fq.gz    61504
# OFHS                                 OFHS.fq.gz    61504
# POF-eye                           POF-eye.fq.gz    61504
# POF-ts                             POF-ts.fq.gz    61504
# PSMGill                           PSMGill.fq.gz    42UL4
# Rope                                 Rope.fq.gz    42UL4
# SMGill                             SMGill.fq.gz    42UL4
# SMHS                                 SMHS.fq.gz    61504
# SN                                     SN.fq.gz    61504
# SPDI                                 SPDI.fq.gz    434JM
# SPK                                   SPK.fq.gz    434JM
# SPPI                                 SPPI.fq.gz    434JM
# SW2-Gill                         SW2-Gill.fq.gz    614H7
# SW2-Intestine-a           SW2-Intestine-a.fq.gz    614H7
# SW2-Intestine-b           SW2-Intestine-b.fq.gz    614H7
# SW2-Kidney                     SW2-Kidney.fq.gz    614H7
# Stg-1-Intestine           Stg-1-Intestine.fq.gz    614VD
# Stg-1-Kidney                 Stg-1-Kidney.fq.gz    614VE
# Stg-2-Intestine           Stg-2-Intestine.fq.gz    614VD
# Stg-2-Kidney                 Stg-2-Kidney.fq.gz    614VE
# Stg-3-Intestine           Stg-3-Intestine.fq.gz    614VD
# Stg-3-Kidney                 Stg-3-Kidney.fq.gz    614VE
# Stg-4-Intestine           Stg-4-Intestine.fq.gz    614VD
# Stg-4-Kidney                 Stg-4-Kidney.fq.gz    614VE
# Stg-5-Intestine           Stg-5-Intestine.fq.gz    614VD
# Stg-5-Kidney                 Stg-5-Kidney.fq.gz    614VE
# Stg-6-Intestine           Stg-6-Intestine.fq.gz    614VD
# Stg-6-Kidney                 Stg-6-Kidney.fq.gz    614VE
# Stg-7-Intestine           Stg-7-Intestine.fq.gz    614VD
# Stg-7-Kidney                 Stg-7-Kidney.fq.gz    614VE
# brain_paired              brain_paired.qc.fq.gz    30M2H
# mssm_single_s1        mssm_single_s1.trim.fq.gz     mssm
# mssm_single_s2        mssm_single_s2.trim.fq.gz     mssm
# mssm_single_s3        mssm_single_s3.trim.fq.gz     mssm
# mssm_single_s5        mssm_single_s5.trim.fq.gz     mssm
# mssm_single_s6        mssm_single_s6.trim.fq.gz     mssm
# mssm_single_s7        mssm_single_s7.trim.fq.gz     mssm
#
#                                          label meta_type paired    phred  \
# 614GMAAXX_1_1_pf            embryo_stg18_614GM    sample  False  phred33
# 614GMAAXX_2_1_pf            embryo_stg20_614GM    sample  False  phred33
# 614GMAAXX_3_1_pf           embryo_stg22a_614GM    sample  False  phred33
# 614GMAAXX_4_1_pf           embryo_stg22b_614GM    sample  False  phred33
# 614GMAAXX_6_1_pf            embryo_stg23_614GM    sample  False  phred33
# 614GMAAXX_7_1_pf          embryo_stg24c1_614GM    sample  False  phred33
# 614GMAAXX_8_1_pf          embryo_stg24c2_614GM    sample  False  phred33
# AB057JABXX_s_7_pe           brain_larval_AB057    sample   True  phred64
# AI                          intest_adult_614GM    sample  False  phred33
# AK                          kidney_adult_614GM    sample  False  phred33
# BB0582ABXX_s_3_pe           liver_larval_BB058    sample   True  phred64
# BB0582ABXX_s_4_pe             liver_pars_BB058    sample   True  phred64
# BB0582ABXX_s_5_pe            brain_adult_BB058    sample   True  phred64
# BB0582ABXX_s_6_pe      intestine_adult_1_BB058    sample   True  phred64
# BB0582ABXX_s_7_pe      intestine_adult_2_BB058    sample   True  phred64
# BB0582ABXX_s_8_pe        unknown_adult_3_BB058    sample   True  phred64
# FW1-Gill                     gill_freshw_614H7    sample  False  phred33
# FW1-Intestine              intest_freshw_614H7    sample  False  phred33
# FW1-Kidney                 kidney_freshw_614H7    sample  False  phred33
# G81-a                 gill_larval_a_tfm0_614GT    sample  False  phred33
# G81-b                 gill_larval_b_tfm0_61HWC    sample  False  phred33
# G82-a                 gill_larval_a_tfm6_614GT    sample  False  phred33
# G82-b                 gill_larval_b_tfm6_61HWC    sample  False  phred33
# G83-a                gill_larval_a_tfm12_614GT    sample  False  phred33
# G83-b                gill_larval_b_tfm12_61HWC    sample  False  phred33
# Gill                                gill_42UL4    sample  False  phred33
# JV1_liver                     intest_juv_42UKJ    sample  False  phred33
# JV_intest                    liver_juv_b_42UKJ    sample  False  phred33
# JVa_liver                    liver_juv_1_42UKJ    sample  False  phred33
# JVb_liver                    liver_juv_a_42UKJ    sample  False  phred33
# Kidney                            kidney_42UL4    sample  False  phred33
# L81-a                liver_larval_a_tfm0_614GT    sample  False  phred33
# L81-b                liver_larval_b_tfm0_61HWC    sample  False  phred33
# L82-a                liver_larval_a_tfm6_614GT    sample  False  phred33
# L82-b                liver_larval_b_tfm6_61HWC    sample  False  phred33
# L83-1-a            liver_larval_a1_tfm12_614GT    sample  False  phred33
# L83-1-b            liver_larval_b1_tfm12_61HWC    sample  False  phred33
# L83-a               liver_larval_a_tfm12_614GT    sample  False  phred33
# L83-b               liver_larval_b_tfm12_61HWC    sample  False  phred33
# LI                         intest_larval_434JM    sample  False  phred33
# LK                         kidney_larval_434JM    sample  False  phred33
# Lips                                lips_42UL4    sample  False  phred33
# M0_liver                    liver_larval_42UKJ    sample  False  phred33
# M2_liver                      liver_stg2_42UKJ    sample  False  phred33
# M5_liver                      liver_stg5_42UKJ    sample  False  phred33
# Monocytes                      monocytes_61504    sample  False  phred33
# Muscle                    muscle_m_sperm_42UL4    sample  False  phred33
# Neutrophils                  neutrophils_61504    sample  False  phred33
# OFHS                      headskin_f_ovu_61504    sample  False  phred33
# POF-eye                     eye_f_preovu_61504    sample  False  phred33
# POF-ts                 tailskin_f_preovu_61504    sample  False  phred33
# PSMGill                  gill_m_presperm_42UL4    sample  False  phred33
# Rope                        rope_adult_m_42UL4    sample  False  phred33
# SMGill                      gill_m_sperm_42UL4    sample  False  phred33
# SMHS                    headskin_m_sperm_61504    sample  False  phred33
# SN                           supraneural_61504    sample  False  phred33
# SPDI                  intest_distal_pars_434JM    sample  False  phred33
# SPK                          kidney_pars_434JM    sample  False  phred33
# SPPI                    intest_prox_pars_434JM    sample  False  phred33
# SW2-Gill                      gill_saltw_614H7    sample  False  phred33
# SW2-Intestine-a           intest_saltw_a_614H7    sample  False  phred33
# SW2-Intestine-b           intest_saltw_b_614H7    sample  False  phred33
# SW2-Kidney                  kidney_saltw_614H7    sample  False  phred33
# Stg-1-Intestine              intest_stg1_614VD    sample  False  phred33
# Stg-1-Kidney                 kidney_stg1_614VE    sample  False  phred33
# Stg-2-Intestine              intest_stg2_614VD    sample  False  phred33
# Stg-2-Kidney                 kidney_stg2_614VE    sample  False  phred33
# Stg-3-Intestine              intest_stg3_614VD    sample  False  phred33
# Stg-3-Kidney                 kidney_stg3_614VE    sample  False  phred33
# Stg-4-Intestine              intest_stg4_614VD    sample  False  phred33
# Stg-4-Kidney                 kidney_stg4_614VE    sample  False  phred33
# Stg-5-Intestine              intest_stg5_614VD    sample  False  phred33
# Stg-5-Kidney                 kidney_stg5_614VE    sample  False  phred33
# Stg-6-Intestine              intest_stg6_614VD    sample  False  phred33
# Stg-6-Kidney                 kidney_stg6_614VE    sample  False  phred33
# Stg-7-Intestine              intest_stg7_614VD    sample  False  phred33
# Stg-7-Kidney                 kidney_stg7_614VE    sample  False  phred33
# brain_paired                       brain_30M2H    sample   True  phred64
# mssm_single_s1                 brain_ctrl_mssm    sample  False  phred33
# mssm_single_s2                spinal_ctrl_mssm    sample  False  phred64
# mssm_single_s3                 brain_day3_mssm    sample  False  phred64
# mssm_single_s5                spinal_day3_mssm    sample  False  phred64
# mssm_single_s6                brain_day21_mssm    sample  False  phred64
# mssm_single_s7               spinal_day21_mssm    sample  False  phred64
#
#                   q_type strand terms       tissue  url  tissue_c  \
# 614GMAAXX_1_1_pf     NaN    +/-   NaN       embryo  NaN         1
# 614GMAAXX_2_1_pf     NaN    +/-   NaN       embryo  NaN         1
# 614GMAAXX_3_1_pf     NaN    +/-   NaN       embryo  NaN         1
# 614GMAAXX_4_1_pf     NaN    +/-   NaN       embryo  NaN         1
# 614GMAAXX_6_1_pf     NaN    +/-   NaN       embryo  NaN         1
# 614GMAAXX_7_1_pf     NaN    +/-   NaN       embryo  NaN         1
# 614GMAAXX_8_1_pf     NaN    +/-   NaN       embryo  NaN         1
# AB057JABXX_s_7_pe    NaN    +/-   NaN        brain  NaN         0
# AI                   NaN    +/-   NaN       intest  NaN         5
# AK                   NaN    +/-   NaN       kidney  NaN         7
# BB0582ABXX_s_3_pe    NaN    +/-   NaN        liver  NaN         9
# BB0582ABXX_s_4_pe    NaN    +/-   NaN        liver  NaN         9
# BB0582ABXX_s_5_pe    NaN    +/-   NaN        brain  NaN         0
# BB0582ABXX_s_6_pe    NaN    +/-   NaN    intestine  NaN         6
# BB0582ABXX_s_7_pe    NaN    +/-   NaN    intestine  NaN         6
# BB0582ABXX_s_8_pe    NaN    +/-   NaN      unknown  NaN        17
# FW1-Gill             NaN    +/-   NaN         gill  NaN         3
# FW1-Intestine        NaN    +/-   NaN       intest  NaN         5
# FW1-Kidney           NaN    +/-   NaN       kidney  NaN         7
# G81-a                NaN    +/-   NaN         gill  NaN         3
# G81-b                NaN    +/-   NaN         gill  NaN         3
# G82-a                NaN    +/-   NaN         gill  NaN         3
# G82-b                NaN    +/-   NaN         gill  NaN         3
# G83-a                NaN    +/-   NaN         gill  NaN         3
# G83-b                NaN    +/-   NaN         gill  NaN         3
# Gill                 NaN    +/-   NaN         gill  NaN         3
# JV1_liver            NaN    +/-   NaN       intest  NaN         5
# JV_intest            NaN    +/-   NaN        liver  NaN         9
# JVa_liver            NaN    +/-   NaN        liver  NaN         9
# JVb_liver            NaN    +/-   NaN        liver  NaN         9
# Kidney               NaN    +/-   NaN       kidney  NaN         7
# L81-a                NaN    +/-   NaN        liver  NaN         9
# L81-b                NaN    +/-   NaN        liver  NaN         9
# L82-a                NaN    +/-   NaN        liver  NaN         9
# L82-b                NaN    +/-   NaN        liver  NaN         9
# L83-1-a              NaN    +/-   NaN        liver  NaN         9
# L83-1-b              NaN    +/-   NaN        liver  NaN         9
# L83-a                NaN    +/-   NaN        liver  NaN         9
# L83-b                NaN    +/-   NaN        liver  NaN         9
# LI                   NaN    +/-   NaN       intest  NaN         5
# LK                   NaN    +/-   NaN       kidney  NaN         7
# Lips                 NaN    +/-   NaN         lips  NaN         8
# M0_liver             NaN    +/-   NaN        liver  NaN         9
# M2_liver             NaN    +/-   NaN        liver  NaN         9
# M5_liver             NaN    +/-   NaN        liver  NaN         9
# Monocytes            NaN    +/-   NaN    monocytes  NaN        10
# Muscle               NaN    +/-   NaN       muscle  NaN        11
# Neutrophils          NaN    +/-   NaN  neutrophils  NaN        12
# OFHS                 NaN    +/-   NaN     headskin  NaN         4
# POF-eye              NaN    +/-   NaN          eye  NaN         2
# POF-ts               NaN    +/-   NaN     tailskin  NaN        16
# PSMGill              NaN    +/-   NaN         gill  NaN         3
# Rope                 NaN    +/-   NaN         rope  NaN        13
# SMGill               NaN    +/-   NaN         gill  NaN         3
# SMHS                 NaN    +/-   NaN     headskin  NaN         4
# SN                   NaN    +/-   NaN  supraneural  NaN        15
# SPDI                 NaN    +/-   NaN       intest  NaN         5
# SPK                  NaN    +/-   NaN       kidney  NaN         7
# SPPI                 NaN    +/-   NaN       intest  NaN         5
# SW2-Gill             NaN    +/-   NaN         gill  NaN         3
# SW2-Intestine-a      NaN    +/-   NaN       intest  NaN         5
# SW2-Intestine-b      NaN    +/-   NaN       intest  NaN         5
# SW2-Kidney           NaN    +/-   NaN       kidney  NaN         7
# Stg-1-Intestine      NaN    +/-   NaN       intest  NaN         5
# Stg-1-Kidney         NaN    +/-   NaN       kidney  NaN         7
# Stg-2-Intestine      NaN    +/-   NaN       intest  NaN         5
# Stg-2-Kidney         NaN    +/-   NaN       kidney  NaN         7
# Stg-3-Intestine      NaN    +/-   NaN       intest  NaN         5
# Stg-3-Kidney         NaN    +/-   NaN       kidney  NaN         7
# Stg-4-Intestine      NaN    +/-   NaN       intest  NaN         5
# Stg-4-Kidney         NaN    +/-   NaN       kidney  NaN         7
# Stg-5-Intestine      NaN    +/-   NaN       intest  NaN         5
# Stg-5-Kidney         NaN    +/-   NaN       kidney  NaN         7
# Stg-6-Intestine      NaN    +/-   NaN       intest  NaN         5
# Stg-6-Kidney         NaN    +/-   NaN       kidney  NaN         7
# Stg-7-Intestine      NaN    +/-   NaN       intest  NaN         5
# Stg-7-Kidney         NaN    +/-   NaN       kidney  NaN         7
# brain_paired         NaN    +/-   NaN        brain  NaN         0
# mssm_single_s1       NaN    +/-   NaN        brain  NaN         0
# mssm_single_s2       NaN    +/-   NaN       spinal  NaN        14
# mssm_single_s3       NaN    +/-   NaN        brain  NaN         0
# mssm_single_s5       NaN    +/-   NaN       spinal  NaN        14
# mssm_single_s6       NaN    +/-   NaN        brain  NaN         0
# mssm_single_s7       NaN    +/-   NaN       spinal  NaN        14
#
#                                                               color
# 614GMAAXX_1_1_pf   (0.996493656495, 0.998646674437, 0.702575950062)
# 614GMAAXX_2_1_pf   (0.996493656495, 0.998646674437, 0.702575950062)
# 614GMAAXX_3_1_pf   (0.996493656495, 0.998646674437, 0.702575950062)
# 614GMAAXX_4_1_pf   (0.996493656495, 0.998646674437, 0.702575950062)
# 614GMAAXX_6_1_pf   (0.996493656495, 0.998646674437, 0.702575950062)
# 614GMAAXX_7_1_pf   (0.996493656495, 0.998646674437, 0.702575950062)
# 614GMAAXX_8_1_pf   (0.996493656495, 0.998646674437, 0.702575950062)
# AB057JABXX_s_7_pe  (0.552941203117, 0.827450990677, 0.780392169952)
# AI                 (0.991018839443, 0.706528275854, 0.384421383283)
# AK                  (0.98486735961, 0.804705893993, 0.892318345168)
# BB0582ABXX_s_3_pe  (0.738239154395, 0.508542897421, 0.741668604402)
# BB0582ABXX_s_4_pe  (0.738239154395, 0.508542897421, 0.741668604402)
# BB0582ABXX_s_5_pe  (0.552941203117, 0.827450990677, 0.780392169952)
# BB0582ABXX_s_6_pe  (0.703098825847, 0.869942337625, 0.411657060245)
# BB0582ABXX_s_7_pe  (0.703098825847, 0.869942337625, 0.411657060245)
# BB0582ABXX_s_8_pe  (0.991018839443, 0.706528275854, 0.384421383283)
# FW1-Gill           (0.978685122378, 0.507312601454, 0.456655135926)
# FW1-Intestine      (0.991018839443, 0.706528275854, 0.384421383283)
# FW1-Kidney          (0.98486735961, 0.804705893993, 0.892318345168)
# G81-a              (0.978685122378, 0.507312601454, 0.456655135926)
# G81-b              (0.978685122378, 0.507312601454, 0.456655135926)
# G82-a              (0.978685122378, 0.507312601454, 0.456655135926)
# G82-b              (0.978685122378, 0.507312601454, 0.456655135926)
# G83-a              (0.978685122378, 0.507312601454, 0.456655135926)
# G83-b              (0.978685122378, 0.507312601454, 0.456655135926)
# Gill               (0.978685122378, 0.507312601454, 0.456655135926)
# JV1_liver          (0.991018839443, 0.706528275854, 0.384421383283)
# JV_intest          (0.738239154395, 0.508542897421, 0.741668604402)
# JVa_liver          (0.738239154395, 0.508542897421, 0.741668604402)
# JVb_liver          (0.738239154395, 0.508542897421, 0.741668604402)
# Kidney              (0.98486735961, 0.804705893993, 0.892318345168)
# L81-a              (0.738239154395, 0.508542897421, 0.741668604402)
# L81-b              (0.738239154395, 0.508542897421, 0.741668604402)
# L82-a              (0.738239154395, 0.508542897421, 0.741668604402)
# L82-b              (0.738239154395, 0.508542897421, 0.741668604402)
# L83-1-a            (0.738239154395, 0.508542897421, 0.741668604402)
# L83-1-b            (0.738239154395, 0.508542897421, 0.741668604402)
# L83-a              (0.738239154395, 0.508542897421, 0.741668604402)
# L83-b              (0.738239154395, 0.508542897421, 0.741668604402)
# LI                 (0.991018839443, 0.706528275854, 0.384421383283)
# LK                  (0.98486735961, 0.804705893993, 0.892318345168)
# Lips               (0.848304507312, 0.842768175462, 0.848396779509)
# M0_liver           (0.738239154395, 0.508542897421, 0.741668604402)
# M2_liver           (0.738239154395, 0.508542897421, 0.741668604402)
# M5_liver           (0.738239154395, 0.508542897421, 0.741668604402)
# Monocytes          (0.801568639278, 0.921630146924, 0.769903896603)
# Muscle                        (1.0, 0.929411768913, 0.435294121504)
# Neutrophils        (0.552941203117, 0.827450990677, 0.780392169952)
# OFHS               (0.507727826343, 0.694256073587, 0.822237611168)
# POF-eye            (0.749096516301, 0.733656301919, 0.852502892298)
# POF-ts             (0.507727826343, 0.694256073587, 0.822237611168)
# PSMGill            (0.978685122378, 0.507312601454, 0.456655135926)
# Rope               (0.996493656495, 0.998646674437, 0.702575950062)
# SMGill             (0.978685122378, 0.507312601454, 0.456655135926)
# SMHS               (0.507727826343, 0.694256073587, 0.822237611168)
# SN                 (0.978685122378, 0.507312601454, 0.456655135926)
# SPDI               (0.991018839443, 0.706528275854, 0.384421383283)
# SPK                 (0.98486735961, 0.804705893993, 0.892318345168)
# SPPI               (0.991018839443, 0.706528275854, 0.384421383283)
# SW2-Gill           (0.978685122378, 0.507312601454, 0.456655135926)
# SW2-Intestine-a    (0.991018839443, 0.706528275854, 0.384421383283)
# SW2-Intestine-b    (0.991018839443, 0.706528275854, 0.384421383283)
# SW2-Kidney          (0.98486735961, 0.804705893993, 0.892318345168)
# Stg-1-Intestine    (0.991018839443, 0.706528275854, 0.384421383283)
# Stg-1-Kidney        (0.98486735961, 0.804705893993, 0.892318345168)
# Stg-2-Intestine    (0.991018839443, 0.706528275854, 0.384421383283)
# Stg-2-Kidney        (0.98486735961, 0.804705893993, 0.892318345168)
# Stg-3-Intestine    (0.991018839443, 0.706528275854, 0.384421383283)
# Stg-3-Kidney        (0.98486735961, 0.804705893993, 0.892318345168)
# Stg-4-Intestine    (0.991018839443, 0.706528275854, 0.384421383283)
# Stg-4-Kidney        (0.98486735961, 0.804705893993, 0.892318345168)
# Stg-5-Intestine    (0.991018839443, 0.706528275854, 0.384421383283)
# Stg-5-Kidney        (0.98486735961, 0.804705893993, 0.892318345168)
# Stg-6-Intestine    (0.991018839443, 0.706528275854, 0.384421383283)
# Stg-6-Kidney        (0.98486735961, 0.804705893993, 0.892318345168)
# Stg-7-Intestine    (0.991018839443, 0.706528275854, 0.384421383283)
# Stg-7-Kidney        (0.98486735961, 0.804705893993, 0.892318345168)
# brain_paired       (0.552941203117, 0.827450990677, 0.780392169952)
# mssm_single_s1     (0.552941203117, 0.827450990677, 0.780392169952)
# mssm_single_s2     (0.749096516301, 0.733656301919, 0.852502892298)
# mssm_single_s3     (0.552941203117, 0.827450990677, 0.780392169952)
# mssm_single_s5     (0.749096516301, 0.733656301919, 0.852502892298)
# mssm_single_s6     (0.552941203117, 0.827450990677, 0.780392169952)
# mssm_single_s7     (0.749096516301, 0.733656301919, 0.852502892298)

# %% [markdown]
# ## Data

# %% [markdown]
# Create an HDF5 volume to store data needed in the other notebooks; we won't be performing ops directly on it, so use maximum compression to save disk space.

# %%
store = pd.HDFStore(wdir('{}.store.h5'.format(prefix)), complib='zlib', complevel=5)

# %%
import atexit
def exit_func():
    dump_results()
    store.close()
atexit.register(exit_func)
# Out:
# <function __main__.exit_func>

# %%
for fn in resources_df[resources_df.meta_type == 'assembly'].filename:
    screed.read_fasta_sequences(wdir(fn))

# %% [markdown]
# ### Transcript Support

# %%
tpm_df = pd.read_csv(wdir('lamp10.eXpress.tpm.tsv'), delimiter='\t', index_col=0)

# %%
labels = dict(zip(sample_df.filename, sample_df.label))

# %%
tpm_df.rename(columns=labels, inplace=True)

# %%
tpm_df.sort(axis=1, inplace=True)

# %%
store['lamp10.eXpress.tpm.tsv'] = tpm_df
# Out:
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.eXpress.tpm.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/pandas/io/pytables.py:2577: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->unicode,key->axis0] [items->None]
#
#   warnings.warn(ws, PerformanceWarning)
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/pandas/io/pytables.py:2577: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->unicode,key->block0_items] [items->None]
#
#   warnings.warn(ws, PerformanceWarning)

# %% [markdown]
# ### Blast Results

# %%
# %load_ext cython

# %%
# %%cython
# cimport numpy as np
# import numpy as np
# # Returns:
# # [0: sstart
# #  1: send
# #  2: qstart
# #  3: qend
# #  4: sstrand
# #  5: qstrand]
# cdef np.ndarray[long] fix_coords_single(long sstart, long send, long qstart, long qend):
#     cdef np.ndarray[long] res = np.empty(6, dtype=long)
#
#     if sstart < send:
#         res[0] = sstart - 1
#         res[1] = send
#         res[4] = 1
#     else:
#         res[0] = send
#         res[1] = sstart + 1
#         res[4] = -1
#
#     if qstart < qend:
#         res[2] = qstart - 1
#         res[3] = qend
#         res[5] = 1
#     else:
#         res[2] = qend
#         res[3] = qstart + 1
#         res[5] = -1
#
#     return res
#
# cpdef np.ndarray[long, ndim=2] fix_blast_coords(np.ndarray[long] sstart, np.ndarray[long] send,
#                                                     np.ndarray[long] qstart, np.ndarray[long] qend):
#     cdef long n = len(sstart)
#     cdef long i = 0
#     cdef np.ndarray[long, ndim=2] res = np.empty((n,6), dtype=long)
#     for i in range(n):
#         res[i,:] = fix_coords_single(sstart[i], send[i], qstart[i], qend[i])
#     return res

# %%
import blasttools

# %%
def fix_blast_coords_df(df):
    coords = fix_blast_coords(df.sstart.values, df.send.values, df.qstart.values, df.qend.values)
    df['sstart'] = coords[:,0]
    df['send'] = coords[:,1]
    df['qstart'] = coords[:,2]
    df['qend'] = coords[:,3]
    df['sstrand'] = coords[:,4]
    df['qstrand'] = coords[:,5]

# %%
blast_items = resources_df[resources_df.meta_type.isin(['sample', 'assembly', 'gtf_database']) == False]
for i, (dbname, info) in enumerate(blast_items.iterrows()):
    target = '{}.fasta.x.{}.db.tsv'.format('lamp10', info['filename'])
    print dbname, target
    
    df = blasttools.blast_to_df(wdir(target))
    fix_blast_coords_df(df)

    store[target] = df

    tmp = pd.merge(pd.DataFrame(index=tpm_df.index), df,
                      left_index=True, right_index=True, how='left')
    blasttools.best_hits(tmp)

    if i == 0:
        lamp10_best_hits = pd.Panel({target: tmp})
    else:
        lamp10_best_hits[target] = tmp
# Out:
# Myxinidae_pep lamp10.fasta.x.Myx.pep.all.fa.db.tsv
# braFlo_pep
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.Myx.pep.all.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.braFlo.pep.all.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#  lamp10.fasta.x.braFlo.pep.all.fa.db.tsv
# danRer_pep lamp10.fasta.x.danRer.pep.fa.db.tsv
# homSap_pep
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.danRer.pep.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.homSap.pep.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#  lamp10.fasta.x.homSap.pep.fa.db.tsv
# musMus_pep lamp10.fasta.x.musMus.pep.fa.db.tsv
# petMar2
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.musMus.pep.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.petMar2.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#  lamp10.fasta.x.petMar2.fa.db.tsv
# petMar2_cdna lamp10.fasta.x.petMar2.cdna.fa.db.tsv
# petMar2_cds
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.petMar2.cdna.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.petMar2.cds.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#  lamp10.fasta.x.petMar2.cds.fa.db.tsv
# petMar2_ncrna lamp10.fasta.x.petMar2.ncrna.fa.db.tsv
# petMar2_pep
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.petMar2.ncrna.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'lamp10.fasta.x.petMar2.pep.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
#  lamp10.fasta.x.petMar2.pep.fa.db.tsv

# %%
store['lamp10_best_hits'] = lamp10_best_hits
# Out:
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/pandas/io/pytables.py:2577: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['lamp10.fasta.x.Myx.pep.all.fa.db.tsv', 'lamp10.fasta.x.braFlo.pep.all.fa.db.tsv', 'lamp10.fasta.x.danRer.pep.fa.db.tsv', 'lamp10.fasta.x.homSap.pep.fa.db.tsv', 'lamp10.fasta.x.musMus.pep.fa.db.tsv', 'lamp10.fasta.x.petMar2.fa.db.tsv', 'lamp10.fasta.x.petMar2.cdna.fa.db.tsv', 'lamp10.fasta.x.petMar2.cds.fa.db.tsv', 'lamp10.fasta.x.petMar2.ncrna.fa.db.tsv', 'lamp10.fasta.x.petMar2.pep.fa.db.tsv']]
#
#   warnings.warn(ws, PerformanceWarning)

# %%
blast_items = resources_df[resources_df.meta_type.isin(['sample', 'assembly', 'gtf_database']) == False]
for i, (dbname, info) in enumerate(blast_items.iterrows()):
    A_fn = '{}.fasta.x.{}.db.tsv'.format('lamp10', info.filename)
    B_fn = '{}.db.x.{}.fasta.tsv'.format(info.filename, 'lamp10')
    
    print '{} <=> {}'.format(A_fn, B_fn)
    
    A = pd.read_table(wdir(A_fn), header=None, index_col=0, names=outfmt6)
    B = pd.read_table(wdir(B_fn), header=None, index_col=0, names=outfmt6)

    fix_blast_coords_df(A)
    fix_blast_coords_df(B)
    
    X = blasttools.get_orthologies(A, B, tpm_df.index)
    
    if i == 0:
        lamp10_ortho = pd.Panel({A_fn: X})
    else:
        lamp10_ortho[A_fn] = X
# Out:
# lamp10.fasta.x.Myx.pep.all.fa.db.tsv <=> Myx.pep.all.fa.db.x.lamp10.fasta.tsv
# lamp10.fasta.x.braFlo.pep.all.fa.db.tsv <=> braFlo.pep.all.fa.db.x.lamp10.fasta.tsv
# lamp10.fasta.x.danRer.pep.fa.db.tsv <=> danRer.pep.fa.db.x.lamp10.fasta.tsv
# lamp10.fasta.x.homSap.pep.fa.db.tsv <=> homSap.pep.fa.db.x.lamp10.fasta.tsv
# lamp10.fasta.x.musMus.pep.fa.db.tsv <=> musMus.pep.fa.db.x.lamp10.fasta.tsv
# lamp10.fasta.x.petMar2.fa.db.tsv <=> petMar2.fa.db.x.lamp10.fasta.tsv
# lamp10.fasta.x.petMar2.cdna.fa.db.tsv <=> petMar2.cdna.fa.db.x.lamp10.fasta.tsv
# lamp10.fasta.x.petMar2.cds.fa.db.tsv <=> petMar2.cds.fa.db.x.lamp10.fasta.tsv
# lamp10.fasta.x.petMar2.ncrna.fa.db.tsv <=> petMar2.ncrna.fa.db.x.lamp10.fasta.tsv
# lamp10.fasta.x.petMar2.pep.fa.db.tsv <=> petMar2.pep.fa.db.x.lamp10.fasta.tsv

# %%
store['lamp10_ortho'] = lamp10_ortho

# %%
import glob

# %%
glob.glob(wdir('petMar2.cdna.fa.x*.tsv'))
# Out:
# [u'../_work/petMar2.cdna.fa.x.Myx.pep.all.fa.db.tsv',
#  u'../_work/petMar2.cdna.fa.x.homSap.pep.fa.db.tsv',
#  u'../_work/petMar2.cdna.fa.x.petMar2.pep.fa.db.tsv',
#  u'../_work/petMar2.cdna.fa.x.danRer.pep.fa.db.tsv',
#  u'../_work/petMar2.cdna.fa.x.musMus.pep.fa.db.tsv',
#  u'../_work/petMar2.cdna.fa.x.petMar2.fa.db.tsv',
#  u'../_work/petMar2.cdna.fa.x.braFlo.pep.all.fa.db.tsv']

# %%
petMar2_cdna_x_petMar2 = blasttools.blast_to_df(wdir('petMar2.cdna.fa.x.petMar2.fa.db.tsv'))
fix_blast_coords_df(petMar2_cdna_x_petMar2)
store['petMar2.cdna.fa.x.petMar2.fa.db.tsv'] = petMar2_cdna_x_petMar2
# Out:
# /home/camille/miniconda/envs/bio/lib/python2.7/site-packages/tables/path.py:100: NaturalNameWarning: object name is not a valid Python identifier: 'petMar2.cdna.fa.x.petMar2.fa.db.tsv'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)

# %%
lamp10_blast_filter_df = lamp10_best_hits.minor_xs('evalue') >= 0

# %%
lamp10_ortho_filter_df = lamp10_ortho.minor_xs('evalue_x') >= 0

# %%
store['lamp10_blast_filter_df'] = lamp10_blast_filter_df

# %%
store['lamp10_ortho_filter_df'] = lamp10_ortho_filter_df

# %%
tissue_tr_df = (tpm_df > 0).groupby(by=sample_df.sort(columns='label').tissue.values, axis=1).sum()

# %%
store['tissue_tr_df'] = tissue_tr_df

# %%
store.close()
